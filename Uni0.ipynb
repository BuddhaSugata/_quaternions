# %% [markdown]
# # Униметрия. Переосмысление СТО
#
# Мы ощущаем эту реальность как данность,как нулевой уровень дериватива, но что если она вторична?
# Что если реальность, какой мы привыкли её воспринимать - лишь пещера Платона?
#
# ## Время и пространство как производные
# Предположим, что существует абсолютное время $ t $ в противопоставление локальному собственному времени $ \tau $.
# Попробуем, буквально, "в лоб" задать метрические аттрибуты пространства и времени как первую производную некоторой величины по абсолютному времени:
# $$ dx_i = \tilde{X}_i^{(t)} \ dt, \ i = 0..3 \qquad (1) $$
# Как если бы существовало прото-пространство, движение в котором порождает наблюдаемые эффекты времени и пространства. Алгебраически это означает просто, что время-пространственные базовые векторы (единицы, меры) являются скоростью - первой производной какого-то прото-движения.
# В принципе, они не обязытельно должны быть производными по абсолютному времени - для сохранения алгебраической структуры, а именно это нас сейчас интересует, достаточно, чтобы они были производными некой единой переменной величины.
#
# ### Интервал
# Посмотрим на вид интервала СТО $ ds^2 = dx_0^2 - dx_1^2 - dx_2^2 - dx_3^2 $ после подстановки (1):
# $$ ds^2 = \tilde{X}_0^2 \ dt^2 - \tilde{X}_1^2 \ dt^2 - \tilde{X}_2^2 \ dt^2 - \tilde{X}_3^2 \ dt^2 \qquad (2) $$
# и немного преобразуем, разделив всё на квадрат дифференциала абсолютного времени и введя скорость интервала $ ds = \tilde{S} \ dt $ аналогично ранее представленым прото-скоростям:
# $$ \tilde{S}^2 = \tilde{X}_0^2 - \tilde{X}_1^2 - \tilde{X}_2^2 - \tilde{X}_3^2 \qquad (3) $$
# Что после объединения пространственной части $ \tilde{L}^2 = \tilde{X}_1^2 + \tilde{X}_2^2 + \tilde{X}_3^2 $ и перестановки равносильно:
# $$ \tilde{X}_0^2 =  \tilde{S}^2 + \tilde{L}^2  \qquad (4) $$
# Введём $ \tilde{\mathcal{H}} = \tilde{X}_0 $:
# $$ \tilde{\mathcal{H}}^2 =  \tilde{S}^2 + \tilde{L}^2  \qquad (5) $$
# что выглядит как формула сложения скоростей в евклидовом векторном пространстве. Предположим, что так и есть, и определим концепцию этого движения.
#
# ### Концепт потока
# Предположим, что слева в (5) - величина, являющаяся источником всей динамики времени-пространства __некоторого объекта__. Будем называть эту величину __потоком__, а векторное пространство (в математическом смысле, не в физическом), в котором поток существует - __Хора__ (Платон) https://en.wikipedia.org/wiki/Kh%C3%B4ra?utm_source=chatgpt.com.
# Примем также, что правая часть (5) состоит из "внутренней" $ \tilde{S} $ и "внешней" $ \tilde{L} $ динамики.
#
# ### Скорость потока
# Мы стали обозначать скорость тильдой вместо точки, чтобы избежать возможной путаницы в будущем, потому что величина с точкой - это скорость по локальному времени объекта, а тильда - по абсолютному:
# $$ [ \tilde{\mathcal{H}} ], [ \tilde{S} ], [ \tilde{L} ]   = \frac{ \mathtt{прото-пространство} }{ \mathtt{абсолютное \ время} } = \tilde{\chi} $$
#
# ### Объект
# Любое ненулевое значение потока ($ \tilde{\mathcal{H}} \ne 0 $) будет называться __объектом__. Если объект производит собственную систему отсчёта, в которой он находится в покое:
# $$ \tilde{S} = \tilde{\mathcal{H}} \qquad (6) $$
# то можно сказать, что весь поток объекта является ненаблюдаемым (для самого объекта) - внутренним. Будем говорить о таком объекте как о __сложном__ (__массивном__), в противопоставление объекту, который не может находится в покое:
# $$ \tilde{L} = \tilde{\mathcal{H}} \qquad (7) $$
# и весь поток которого внешний. Будем называть его __простым__ объектом.
#
# В общем случае, объект это вектор в пространстве $ (\tilde{S},\tilde{L}), L \in \mathbb{R}^3 $, которое удобно будет представить комплексным: $ \tilde{V} = e^{z}, z \in \mathbb{C}: \Re(\tilde{V}) = \tilde{S}; \ \Im(\tilde{V}) = \tilde{L}; \ |\tilde{V}| = \tilde{\mathcal{H}} $.
#
# Из (6) и (7) совместно следует, что поток сложного объекта всегда движется вдоль реальной оси с той же скоростью $ \tilde{\mathcal{H}} $, с которой простые объекты движутся перпендикулярно ему - вдоль мнимой. Таким образом, скорость потока является не свойством отдельно взятого изолированного объекта, а может быть скорее представлена гладко изменяющимся скалярным полем над прото-пространством. Кажется, это всё, что пока можно постулировать о ней на данном этапе.

# %% [markdown]
# ### Воспринимаемое время
# Поток постоянно движется, и его скорость влияет на восприятие времени объектом. Как?
# Введём величину $ \tau $ для обозначения локального времени объекта (по его часам).
# Предположим, что объектом является стабильно повторяющийся, циклический процесс (например, излучение при переходе между двумя сверхтонкими уровнями энергии основного состояния атома цезия-133, находящегося в покое при 0 К), тогда в потоке большей скорости он будет происходить, очевидно, чаще, чем в потоке с меньшей, то есть локальное время будет течь быстрее.
# Это напрямую следует из (1) - большей скорости $ \tilde{X}_0^{(t)} > \tilde{Y}_0^{(t)} $ соответствует большая величина дифференциала $ dx_0 > dy_0 $, следовательно, относительный темп времени для него выше, чем для объекта с меньшей скоростью: $ dx_0 / dy_0 > 1 $, и, естественно, наоборот.
# Для удобства формализации введём замкнутую геометрию оси $ x_0 $ в виде окружности фиксированного радиуса $ \mathtt{R} $.
# Тогда с одной стороны мы имеем "частоту" объекта в прото-пространстве (частота в кавычках, потому что размерность у неё отсутствует) как количество циклов объекта, совершаемое за фиксированное абсолютное время:
# $$ \nu = \frac{ T }{ T_{cycle} }, \quad \mathtt{где} \ T_{cycle} = \frac{2 \pi \mathtt{R}}{ \tilde{X}_0^{(t)} } $$
# Введём коэффициент $ k = T / 2 \pi \mathtt{R} $:
# $$ \nu = k \tilde{X}_0^{(t)}, \ [] $$
# С другой стороны, данная частота является отношением абсолютного времени к локальному:
# $$ \nu = \frac{\Delta t}{\Delta \tau} \overset{\mathtt{R} \rightarrow 0}{\implies} \nu = \frac{dt}{d\tau} $$
# Итого:
# $$  d\tau = \frac{dt}{k \tilde{X}_0^{(t)}} \quad (8) $$

# %% [markdown]
# ### Абсолютное время
#
# Перепараметризируем темпоральную компоненту из (1) локальным временем:
# $$ dx_0 = \tilde{X}_0^{(t)} dt = \frac{dx_0}{dt} \frac{dt}{d\tau} \ d\tau = \tilde{X}_0^{(t)} \dot{t} \ d\tau = \tilde{X}_0^{(\tau)} \ d\tau \quad (9) $$
# Откуда, например, видно, что скорость абсолютного времени по локальному равна:
# $$ \frac{dt}{d\tau} = \dot{t} $$
# когда ранее получено:
# $$ \frac{dt}{d\tau} = k \tilde{X}_0^{(t)} $$
# Тогда:
# $$ dx_0 = \tilde{X}_0^{(t)} \ k \ \tilde{X}_0^{(t)} d\tau $$
# $$ dx_i = \tilde{X}_i^{(t)} \ k \ \tilde{X}_0^{(t)} d\tau $$
#
# $$ ds^2 = \left[ 1 - \tilde{X}_1^2 / \tilde{X}_0^2 - \tilde{X}_2^2 / \tilde{X}_0^2 - \tilde{X}_3^2 / \tilde{X}_0^2 \right] k^2 \ \tilde{X}_0^4 d\tau^2 \qquad (2) $$

# %% [markdown]
# ### Пространство
# Простой объект представляет собой максимально возможное перемещение в пространстве, равное максимальной скорости "разворачивания" пространства в данной точке прото-пространства, из (7) следует:
# $$ \mathtt{c} = \frac{ \tilde{L} }{ \tilde{T} } = \frac{ \tilde{\mathcal{H}} }{ \tilde{T} } = 1 \ [] $$
# Заметьте, эта величина возникает в модели натурально, ограничивая максимальную скорость распротранения любых взаимодействий - скорость их распространения не может превышать скорость "генерации" пространства, что замечательно консонирует с наблюдаемыми в природе эффектами, и поэтому в конечном счёте даёт возможность использовать её для локального задания универсальных метрик расстояний и времени внутри любой возможной конфигурации потока.
# Однако, теоретически возникающая величина безразмерна в противопоставление известной скорости света. Почему так?
#
# Это связано с тем, как мы, находясь внутри динамического пространства-времени, воспринимаем время.
#
#
#
# ### Масштаб скорости взаимодействий
# Натурально возникающей величиной, отражающей масштаб скоростей в любой конфигурации потока, является отношение внешнего - пространственного - потока, задающего масштаб пространства, к полному потоку, характеризующему локальную скорость течения времени:
# $$ \mathtt{[v]} = \frac{\tilde{L}}{\tilde{T}} \in [0..1] $$
# Из (7) следует, что движение любого простого - пространственно ориентированного - объекта относительно любого сложного будут происходить со скоростью:
# $$ \mathtt{c} = 1 \left[ \frac{\tilde{L} }{\tilde{T}} \right] \qquad (8) $$
# ведь их векторы всегда строго ортогональны.
# Заметим, что если данное отношение __для объекта__ равно единице - весь поток является внешним или пространственным - то мы получаем нулевое значение
#
# ### 1
# $$ dx_i = \tilde{X}_i \dot{X}_0 \ d\tau, \quad i = 0..3 $$
#
# Однако, с учётом того, что объект-поток может быть наблюдаем также и со стороны, удобно будет ввести угол отклонения потока $ \chi $, характеризующий обстоятельства его наблюдения:
# $$ \cos \chi = \frac{\tilde{S}}{\tilde{T}}; \quad \sin \chi = \frac{\tilde{L}}{\tilde{T}}; \quad \tan \chi = \frac{\tilde{L}}{\tilde{S}} $$

# %% [markdown]
# $$ g_{\mu \nu} = \begin{pmatrix} \mathtt{c} d \tilde{T} & 0 & 0 & 0 \\ 0 & \tilde{X}_1 & 0 & 0 \\ 0 & 0 & \tilde{X}_2 & 0 \\ 0 & 0 & 0 & \tilde{X}_3 \end{pmatrix} \ dt $$
# Пространство - преимущественно через простые объекты, время - преимущественно через сложные. Если наделить $ \tilde{L} $ рамерностью $ [ L ] $, а $ \tilde{T} $ соответственно - $ [ T ] $, то получается, что

# %% [markdown]
# Перепараметризируем темпоральную компоненту из (1) локальным временем:
# $$ dx_0 = \tilde{X}_0^{(t)} dt = \frac{dx_0}{dt} \frac{dt}{d\tau} \ d\tau = \tilde{X}_0^{(t)} \dot{X}_0 \ d\tau = \tilde{X}_0^{(\tau)} \ d\tau \quad (8) $$
# Для двух разных объектов получается:
# $$ d\tau_x = \frac{d\tau_x}{ \tilde{X}_0 } = \frac{d\tau_y}{ \tilde{Y}_0 } \Rightarrow \frac{d\tau_x}{d\tau_y} = \frac{ \dot{Y}_0 }{ \dot{X}_0 }$$

# %%
Для двух разных объектов получается:
$$ dt = \dot{X}_0 \ d\tau_x; \ dt = \dot{Y}_0 \ d\tau_y \Rightarrow \frac{d\tau_x}{d\tau_y} = \frac{\dot{Y}_0}{\dot{X}_0} = \frac{\tilde{X}_0^{(t)}}{\tilde{Y}_0^{(t)}} \frac{\tilde{Y}_0^{(\tau)}}{\tilde{X}_0^{(\tau)}} $$
Если один цикл — это фиксированное расстояние в прото-пространстве, пройденное вдоль оси $ x_0 $ (то есть длина $ dx_0 $ прямо пропорциональна времени одного действия), то наблюдаемая длительность одного действия (т.е. локальный период $ d\tau $) связана с тем, насколько длинным является этот $ dx_0 $: чем короче $ dx_0 $, тем медленнее идёт время - длинее $ d\tau $. Значит:
$$ d\tau \propto \frac{1}{dx_0} = \frac{1}{\tilde{X}_0^{(t)} \ dt} $$

Таким образом, в то время как прото-длины прямопропорциональны абсолютному времени, локальное время воспринимается обратнопропорционально изменению длины в прото-пространстве, а следовательно и абсолютному времени: чем выше скорость потока, тем меньше абсолютного времени нужно на период колебания, и, значит, время течёт быстрее. 
А если время абсолютно, то оно должно быть универсальным инвариантом для всех систем отсчёта, следовательно, справа - тоже инвариант:

Получается, что секунда, например, по определению является 9 192 631 770 колебаний определённого объекта - атома цезия-133 в заданных условиях - в обстоятельствах наблюдателя (читай, с той же скоростью потока, что и наблюдателя), в нашей концепции период одного колебания будет: 
$$ 1 \ [s] = 9 192 631 770 \frac{ [\mathtt{ \chi \ одного \ колебания }] }{  \tilde{\mathcal{H}} \ [ \tilde{\chi} ] } \propto \tilde{\mathcal{H}}^{-1} , \quad [\mathtt{абсолютное \ время}] $$
Абсолютное время периода одного колебания обратнопропорционально скорости потока, а значит в области большей скорости потока за одинаковый промежуток абсолютного времени произойдёт больше колебаний, следовательно, время течёт быстрее или с темпом прямопропорциональным скорости потока, но в единицах обратнопропорциональных скорости потока.

Выходит, что секунды и любые другие меры времени, которые мы используем также подходят для описания абсолютного времени.


Единицы расстояния в динамическом пространстве задаются как расстояние, проходимое на максимальной скорости за определённое время, например:
$$ 1 \ [m] = \mathtt{c} \ \frac{1}{299729458} \ 9 192 631 770 \frac{ [\mathtt{ \chi \ одного \ колебания }] }{  \tilde{\mathcal{H}} \ [ \tilde{\chi} ] } = 30,67 \mathtt{c} \frac{ [\mathtt{ \chi \ одного \ колебания }] }{  \tilde{\mathcal{H}} \ [ \tilde{\chi} ] } $$
