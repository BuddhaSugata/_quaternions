# %% [markdown]
# # Униметрия. Переосмысление СТО
#
# Мы ощущаем эту реальность как данность,как нулевой уровень дериватива, но что если она вторична?
# Что если реальность, какой мы привыкли её воспринимать - лишь пещера Платона?
#
# ### 1. Время и пространство как производные
# Предположим, что существует абсолютное время $ t $ в противопоставление локальному собственному времени $ \tau $.
# Попробуем, буквально, "в лоб" задать метрические аттрибуты пространства и времени как первую производную некоторой величины по абсолютному времени:
# $$ dx_i = \tilde{X}_i \ dt, \ i = 0..3 \in \mathbb{Z} \qquad (1.1) $$
# Как если бы существовало прото-пространство, движение в котором порождает наблюдаемые эффекты времени и пространства. Алгебраически это означает просто, что время-пространственные базовые векторы (единицы, меры) являются скоростью - первой производной какого-то прото-движения.
# В принципе, они не обязательно должны быть производными по абсолютному времени - для сохранения алгебраической структуры, а именно это нас сейчас интересует, достаточно, чтобы они были производными некой единой переменной величины. Как минимум, воизбежание путаницы обозначим эту величину $ \chi $:
# $$ dx_i = \tilde{X}_i \ d\chi, \ i = 0..3 \in \mathbb{Z} \qquad (1.2) $$
#
# ### 2. Интервал
# Посмотрим на вид интервала СТО $ ds^2 = dx_0^2 - dx_1^2 - dx_2^2 - dx_3^2 $ после подстановки (1.2):
# $$ ds^2 = \tilde{X}_0^2 \ d\chi^2 - \tilde{X}_1^2 \ d\chi^2 - \tilde{X}_2^2 \ d\chi^2 - \tilde{X}_3^2 \ d\chi^2 \qquad (2.1) $$
# и немного преобразуем, разделив всё на квадрат дифференциала абсолютного времени и введя скорость интервала $ ds = \tilde{S} \ d\chi $ аналогично ранее представленым прото-скоростям:
# $$ \tilde{S}^2 = \tilde{X}_0^2 - \tilde{X}_1^2 - \tilde{X}_2^2 - \tilde{X}_3^2 \qquad (2.2) $$
# Что после объединения пространственной части $ \tilde{L}^2 = \tilde{X}_1^2 + \tilde{X}_2^2 + \tilde{X}_3^2 $ и перестановки равносильно:
# $$ \tilde{X}_0^2 =  \tilde{S}^2 + \tilde{L}^2  \qquad (2.3) $$
# Введём $ \tilde{\mathcal{H}} = \tilde{X}_0 $:
# $$ \tilde{\mathcal{H}}^2 =  \tilde{S}^2 + \tilde{L}^2  \qquad (2.4) $$
# что выглядит как формула сложения скоростей в евклидовом векторном пространстве. Предположим, что так и есть.
# Что у нас есть? Видно, что если представить время-пространство индуцированым изменением единого параметра, то величина скорости данного параметра вдоль темпоральной координатной оси может быть представлена как сумма скоростей вдоль двух отдельных компонент - пространственной и вне-пространственной (наблюдаемой и ненаблюдаемой, внешней и внутренней).
#
# ### 3. Концепт потока
# Предположим, что слева в (2.4) - величина, являющаяся источником всей динамики времени-пространства __некоторого объекта__. Будем называть эту величину __потоком__, а векторное пространство (в математическом смысле, не в физическом), в котором поток существует - __Хора__ (Платон) https://en.wikipedia.org/wiki/Kh%C3%B4ra?utm_source=chatgpt.com.
# Примем также, что правая часть (2.4) состоит из "внутренней" $ \tilde{S} $ и "внешней" $ \tilde{L} $ динамики.
#
# ### 4. Скорость потока
# Мы стали обозначать скорость тильдой вместо точки, чтобы избежать возможной путаницы в будущем, потому что величина с точкой - это скорость по локальному времени объекта, а тильда - по абсолютному:
# $$ [ \tilde{\mathcal{H}} ], [ \tilde{S} ], [ \tilde{L} ]   = \frac{ \mathtt{прото-пространство} }{ \mathtt{абсолютное \ время} } = \tilde{\chi} $$
#
# ### 5. Объект
# Любое ненулевое значение потока ($ \tilde{\mathcal{H}} \ne 0 $) будет называться __объектом__. Если объект производит собственную систему отсчёта, в которой он находится в покое:
# $$ \tilde{S} = \tilde{\mathcal{H}} \qquad (5.1) $$
# то можно сказать, что весь поток объекта является ненаблюдаемым (для самого объекта) - внутренним. Будем говорить о таком объекте как о __сложном__ (__массивном__), в противопоставление объекту, который не может находится в покое:
# $$ \tilde{L} = \tilde{\mathcal{H}} \qquad (5.2) $$
# и весь поток которого внешний. Будем называть его __простым__ объектом.
# Таким образом, сложным объектом на языке современной физики будет являться любое __событие__ в смысле СТО или череда таковых - мировая линия, а простым - фрагмент подпространства нулевого интервала, содержащий информацию о __событии__.
# В общем случае, объект это вектор в пространстве $ (\tilde{S},\tilde{L}), L \in \mathbb{R}^3 $, которое удобно будет представить комплексным: $ \tilde{V} = e^{z}, z \in \mathbb{C}: \Re(\tilde{V}) = \tilde{S}; \ \Im(\tilde{V}) = \tilde{L}; \ |\tilde{V}| = \tilde{\mathcal{H}} $.
# Из (5.1) и (5.2) совместно следует, что поток сложного объекта всегда движется вдоль реальной оси с той же скоростью $ \tilde{\mathcal{H}} $, с которой простые объекты движутся перпендикулярно ему - вдоль мнимой. Таким образом, скорость потока является не свойством отдельно взятого изолированного объекта, а может быть скорее представлена гладко изменяющимся скалярным полем над прото-пространством. Кажется, это всё, что пока можно постулировать о ней на данном этапе.
# Эффекты СТО же достигаются трансляцией точки в пространстве $ (\tilde{S}, \tilde{L}) $ вдоль мнимой оси (с сохранением реальной части - интервала). Очевидно, такое преобразование не является ортогональным - норма вектора $ |\tilde{V}| = \tilde{\mathcal{H}} $ увеличится.
# Противоречие возникает от того, что если объект А движется относительно объекта Б, то норма скорости потока А будет больше, но вместе с тем, объекта Б движется в ИСО объекта А, где норма потока А должна быть меньше, чем норма потока Б. Полагаю именно эта неурядица с нормами привела к использованию гиперболического инструментария. Что делать, если мы хотим оставить евклидову метрику?
# Принять, что норма относительна в части движения. Такое в физике уже было, это не большая проблема. Большая проблема возникает с сохранением постоянства скорости света. Но что если мы покажем механизм её сохранения в новом представлении?
#
# ### 6. Время
# Для начала необходимо разобраться с масштабированием времени и пространства скоростью потока. Из (1.2) можем записать:
# $$ \tilde{S}^2 = \frac{ds^2}{d\chi^2} = \frac{g_{ij} dx^i dx^j}{d\chi^2} = \begin{pmatrix} \tilde{X}_0^2 & 0 & 0 & 0 \\ 0 & \tilde{X}_1^2 & 0 & 0 \\ 0 & 0 & \tilde{X}_2 & 0 \\ 0 & 0 & 0 & \tilde{X}_3^2 \end{pmatrix}  \quad (6.1) $$
# Скорость потока вдоль темпоральной оси прежде всего прочего нормирует воприятие обстоятельств:
# $$ dx_0 = \tilde{X}_0 \ d\chi = \frac{dx_0}{d\chi} \textcolor{blue}{ \frac{d\chi}{d\tau} } \ d\tau = \tilde{X}_0 \textcolor{blue}{ \dot{\chi} } \ d\tau \quad (6.2) $$
# Скорость течения потока, выраженная в локальном времени, будет произвдением двух скоростей - скорости потока по единому прото-параметру и скорость этого параметра по локальному времени.
# Из наличия в окружающем мире большого числа частотных явлений неясного генеза, предположим, что локальное время возникает как результат совершения объектами некоторого циклического действия, как если бы геометрию оси $ x_0 $ была замкнутой. Упрощённо представим её окружностю варьируемого радиуса $ R $, тогда в высокочастотном пределе имеем:
# $$ \nu = \frac{\Delta \chi}{\Delta \tau} \overset{R \rightarrow 0}{\implies} \nu = \frac{d\chi}{d\tau} = \textcolor{blue}{ \dot{\chi} } \quad (6.3) $$
# где $ \Delta \chi = 2 \pi R_1, \ \Delta \tau = 2 \pi R_2 / \tilde{X}_0 $, следовательно, частота $ \nu = k \tilde{X}_0, \ k = R_1 / R_2 $, а значит и скорость прото-параметра: $$ \boxed{ \textcolor{blue}{ \dot{\chi} } = k \tilde{X}_0 }  \quad (6.4)$$
# <div class="alert alert-block alert-info"> <b>Примечание.</b> При заданных упрощённо в виде окружности циклических формах, частота всегда будет линейной функцией скорости потока и без предельного условия, однако важно понимать, что это лишь упрощение, и реальные формы конфигурации потока микрообъектов могут быть сложнее, а значит, введённый коэффициент <b>k</b> совсем не обязан быть линейным для объектов такого масштаба, но для сложносоставных объектов будет их количественной характеристикой. </div>
# Это ключевая точка всей теории. Мало того, что метрика генерируется изменением какого-то прото-параметра, но она ещё должна быть описана в динамике воспринимаемой реальности - относительно времени как мы его проживаем (из 6.1 и 6.4):
# $$ dS^2 = ds^2 = \frac{g_{ij} dx^i dx^j}{d\chi^2} \frac{d\chi^2}{d\tau^2} d\tau^2 = \begin{pmatrix} \tilde{X}_0^2 & 0 & 0 & 0 \\ 0 & \tilde{X}_1^2 & 0 & 0 \\ 0 & 0 & \tilde{X}_2 & 0 \\ 0 & 0 & 0 & \tilde{X}_3^2 \end{pmatrix} k^2 \tilde{X}_0^2 d\tau^2  \quad (6.5) $$
# Отсюда следует, что полная величина потока в локальном времени:
# $$ \boxed{ \dot{\mathcal{H}} = k \tilde{X}_0^2 }  \quad (6.6) $$
#
#
# ### 6. Представление события в разных ИСО
#
# Пусть в прото-пространстве (Хоре) происходит некоторое событие \$\mathcal{E}\$ — например, пересечение или взаимодействие двух объектов. Попробуем описать его с точки зрения двух различных инерциальных систем отсчёта (ИСО), опираясь на ранее введённую концепцию потока.
#
# #### 6.1 Постановка
#
# Рассмотрим два объекта A и B, обладающие ненулевым потоком \$\tilde{\mathcal{H}}\$, то есть представляющие собой объекты в смысле раздела 5. Пусть объект A в системе \$K\$ находится в состоянии покоя, а объект B движется с некоторой внешней составляющей потока \$\tilde{L}\_B > 0\$.
#
# В системе \$K\$:
#
# * Поток объекта A: $\tilde{V}_A = \tilde{\mathcal{H}},\quad \tilde{S}_A = \tilde{\mathcal{H}},\quad \tilde{L}_A = 0$
# * Поток объекта B: $\tilde{V}_B = \tilde{S}_B + i \tilde{L}_B,\quad \tilde{S}_B^2 + \tilde{L}_B^2 = \tilde{\mathcal{H}}^2$
#
# Пусть событие \$\mathcal{E}\$ происходит в момент \$\chi\$ абсолютного времени, и координаты события в системе \$K\$ определяются выражением:
# $dx^\mu = \tilde{X}_B^\mu\ d\chi \quad \mu = 0..3$
#
# #### 6.2 Переход к системе \$K'\$
#
# Теперь рассмотрим систему \$K'\$, связанную с объектом B. В ней:
#
# * Объект B находится в покое: $\tilde{L}_B' = 0,\quad \tilde{S}_B' = \tilde{\mathcal{H}}$
# * Объект A теперь движется, его поток в \$K'\$ будет:
#   $\tilde{V}_A' = \tilde{S}_A' + i \tilde{L}_A',\quad (\tilde{S}_A')^2 + (\tilde{L}_A')^2 = \tilde{\mathcal{H}}^2$
#
# Событие \$\mathcal{E}\$ будет иметь другие координаты \$dx'^\mu\$ в \$K'\$:
# $dx'^\mu = \tilde{X}_A'^\mu\ d\chi$
#
# Таким образом, **одно и то же событие** в двух различных ИСО представлено через различные проекции одного и того же прото-движения на наблюдаемое время и пространство.
#
# #### 6.3 Геометрия перехода
#
# Переход от одной ИСО к другой интерпретируется как **поворот вектора потока \$\tilde{V}\$ в комплексной плоскости** \$ (\tilde{S}, \tilde{L}) \$. Угол поворота \$\theta\$ между ориентациями потока в разных ИСО задаётся отношениями:
# $\cos(\theta) = \frac{\tilde{S}}{\tilde{\mathcal{H}}},\quad \sin(\theta) = \frac{\tilde{L}}{\tilde{\mathcal{H}}}$
#
# Модуль потока \$|\tilde{V}| = \tilde{\mathcal{H}}\$ сохраняется, как и интервал \$ds^2\$, что делает данный переход аналогом Лоренцева преобразования.
#
# Можно даже записать аналог матрицы гиперболического поворота:
#
# $$
# \begin{pmatrix}
#  dx_0' \\
#  dx_1'
# \end{pmatrix}
# =
# \begin{pmatrix}
#  \cosh\phi & -\sinh\phi \\
#  -\sinh\phi & \cosh\phi
# \end{pmatrix}
# \begin{pmatrix}
#  dx_0 \\
#  dx_1
# \end{pmatrix},
# $$
#
# где \$\phi\$ — гиперболический угол между ориентациями потоков объектов A и B.
#
# #### 6.4 Вывод
#
# Одно и то же событие в разных ИСО описывается различными проекциями одного и того же потока в Хоре. Смена ИСО соответствует изменению ориентации наблюдателя относительно направления потока, а преобразование между ними геометрически сводится к гиперболическому повороту. Интервал и модуль потока при этом остаются инвариантами.
#
# Это подчёркивает, что пространственно-временная картина мира вторична и возникает как результат наблюдения движения потоков в более фундаментальной структуре — Хоре.
#
# ### Пространство
# Интервал необходим для пересчёта физических масштабов времени и пространства из обстоятельств одного объекта в обстоятельства другого объекта. Будем называть второй объект наблюдаетелем. Так любой инерциально движущийся объект видимый наблюдателю описывается интервалом, в котором используются время по часам наблюдателя и пространственные измерения в обстоятельствах наблюдателя.
# Как измеряются пространственные компоненты наблюдателя? Пространство наблюдателя это всегда пространство создаваемое совокупностью других объектов.
# Итак, пусть существует некоторое векторное пространство, в каждой точке которого находится покоящийся объект с $ dx_0^2 = \mathtt{c}^2 d\tau^2 $. Пусть происходит событие с координатами $ (x_1, y_1, z_1) $
#
# ### Воспринимаемое время
# Поток постоянно движется, и его скорость влияет на восприятие времени объектом. Как?
# Введём величину $ \tau $ для обозначения локального времени объекта (по его часам).
# Предположим, что объектом является стабильно повторяющийся, циклический процесс (например, излучение при переходе между двумя сверхтонкими уровнями энергии основного состояния атома цезия-133, находящегося в покое при 0 К), тогда в потоке большей скорости он происходил бы, очевидно, чаще, чем в потоке с меньшей, то есть локальное время будет течь быстрее.
# Это напрямую следует из (1) - большей скорости $ \tilde{X}_0 > \tilde{Y}_0 $ соответствует большая величина дифференциала $ dx_0 > dy_0 $, следовательно, относительный темп времени для него выше, чем для объекта с меньшей скоростью: $ dx_0 / dy_0 > 1 $, и, естественно, наоборот.
# Но $ \tilde{X}_0 $ чересчур похож на мега-известную константу, поэтому мы оставим его фиксированным, а для создания эффекта разного течения времени введём замкнутую геометрию оси $ x_0 $ в виде окружности варьируемого радиуса $ \mathtt{R} $.
# Тогда с одной стороны мы имеем частоту эмитируемого объекта в прото-пространстве как количество событий за локальное время:
# $$ \nu = \frac{ T }{ T_{cycle} }, \quad \mathtt{где} \quad T_{cycle} = \frac{2 \pi \mathtt{R}}{ \tilde{X}_0 } $$
# Введём коэффициент $ k = T / 2 \pi \mathtt{R} $:
# $$ \nu = k \tilde{X}_0, \ [Hz] $$
# Строго говоря, мы должны бы получить безразмерную величину из отношения времени ко времени, но проблема в том, что если мы умножим эту частоту объекта на локальное время, то получим количество
# С другой стороны, данная "частота" является отношением периодов в абсолютном времени и в локальном:
# $$ \nu = \frac{\Delta t}{\Delta \tau} {\implies} \nu = \frac{dt}{d\tau} $$
# Итоговая зависимость между абсолютным и локальным временем:
# $$  \frac{dt}{d\tau} = k \ \tilde{X}_0 $$
# Важно отметить, что темп течения локального времени обратно пропорционален длине пути в прото-пространстве, необходимого на один "тактовый" цикл. То есть, чем меньше $ \mathtt{R} $, тем меньше абсолютного времени нужно объекту на завершение цикла — и, соответственно, тем быстрее, с его точки зрения, течёт время. В этом смысле восприятие времени геометризовано: длина окружности становится масштабным фактором.
# Теперь перепараметризируем темпоральную компоненту из (1) локальным временем:
# $$ dx_0 = \tilde{X}_0 \ dt = \frac{dx_0}{dt} \frac{dt}{d\tau} \ d\tau = \tilde{X}_0 \dot{t} \ d\tau = \dot{x}_0 \ d\tau \quad (9) $$
# Откуда, например, видно, что скорость абсолютного времени по локальному равна:
# $$ \frac{dt}{d\tau} = \dot{t} $$
# Тогда скорость объекта вдоль темпоральной оси, выраженная в локальном времени, является нормой объекта в пространстве $ (\tilde{S}, \tilde{L})$, адаптированной к внутреннему вопроиятию:
# $$ \dot{x}_0 = \frac{dx_0}{d\tau} = k \ \tilde{X}_0^2 $$
# А величина $ dt = dx_0 / \tilde{X}_0 = k \ \tilde{X}_0 d\tau $ будет инвариантом как следствие абсолютности времени.
#
# _добавь комментарий об обратном характере зависимости между локальным и абсолютным временем_
# _получается, что в приведённом принципе геометризации времени заложена конструкция, которая приводит к "заквадрачиванию" скорости потока_
#
# Если $ \mathtt{R} $ является аттрибутом объекта (тогда как прото-скорость - аттрибут векторного пространства), то может меняться во времени, например, в результате взаимодействий с другими объектами:
# $$ \tilde{k} = -\frac{ \tilde{\mathtt{R}} }{ 2 \pi \mathtt{R}^2 } , \quad \dot{k} = -\frac{ k \ \tilde{X}_0 \tilde{\mathtt{R}} }{ 2 \pi \mathtt{R}^2 } = -\frac{ k^2 \ \tilde{X}_0^2 \dot{\mathtt{R}} }{ 2 \pi \mathtt{R}^2 } \Rightarrow \dot{(-k^{-1})} = -\frac{  \tilde{X}_0^2 }{ 2 \pi } \dot{(\mathtt{-R^{-1}})} \Rightarrow k = -\frac{2 \pi \mathtt{R}}{\tilde{X}_0^2} $$
#
# ### Радиус-фактор объекта
# Мы ввели некий радиус-фактор объекта, чтобы упрощённо параметризовать его поведение во времени. Для сложного объекта
#
# ### Пространство
# Пространство возникает как совокупность объектов и их взаимного положения.

# %% [markdown]
# $$ dx_i = \tilde{X}_i^{(t)} \ k \ \tilde{X}_0^{(t)} d\tau $$
#
# $$ ds^2 = \left[ 1 - \tilde{X}_1^2 / \tilde{X}_0^2 - \tilde{X}_2^2 / \tilde{X}_0^2 - \tilde{X}_3^2 / \tilde{X}_0^2 \right] k^2 \ \tilde{X}_0^4 d\tau^2  $$
# А скорость простого объекта вдоль пространственной оси в локальном времени:
# $$ \dot{x}_i = \frac{dx_i}{d\tau} = \tilde{X}_i \frac{dt}{d\tau} = \tilde{X}_i \ k \ \tilde{X}_0, \quad i = 1..3 \in \mathbb{Z} $$
