# %% [markdown]
# # Униметрия. Прото-функция
#
# Мы ощущаем эту реальность как данность, как нулевой уровень дериватива, но что если она вторична?
# Что если реальность, какой мы привыкли её воспринимать - лишь [пещера Платона](https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%84_%D0%BE_%D0%BF%D0%B5%D1%89%D0%B5%D1%80%D0%B5)?
# В статье рассмотрена возможность варьирования метрики пространства-времени с помощью концепции, в которой время и пространство вторичны относительно изменения некоторого единого __прото-параметра__ - фазы, с целью получения математической модели, вопроизводящей эффекты специальной теории относительности в более фундаментальном представлении, и оставляющей возможность для распространения применённых принципов на объединение с другими актуальными теориями.
# Мы предполагаем, что метрика пространства-времени - это своего рода оболочка, презентующая законы природы в тех терминах, которые нам наиболее естественны - представление о которых, сложилось исторически натурально. Но позволим себе взглянуть на вещи иначе и предположим, что время - это мера относительной скорости протекания циклов, а не самостоятельная фундаментальная величина. Тогда темпоральную ось теорий относительности вполне законномерно можно представить длиной, которую составные частицы массивного объекта проходят в ненаблюдаемой части пространства. Однако, и длина не может являться фундаментальной величиной, потому что зависит от масштаба, от базисного вектора, то есть по сути относительна.
# Отсюда вытекает допущение, давшее название статье - и время, и пространство могут и должны быть заданы единой величиной, чтобы дать место существованию математического объяснения постоянства скорости света и сохранения интервала в гиперболическом пространстве.
# В статье мы ищем формализм, в котором СТО естественно вытекает из математики более фундаментального параметра, и оба эффекта воспроизводятся как результат сохранения фазовых свойств объектов. Фундаментальной величиной при этом, очевидно, будет служить фаза, потому что угол абсолютен в евклидовом пространстве, которое, следовательно, также принято фундаментальным.
#
# ## 1. Время и пространство как производные
# Предположим, что существует переменная величина, назовём её обезличенно $ \chi $, изменение которой порождает наблюдаемые эффекты времени и пространства. Алгебраически это означает просто, что время-пространственные базовые векторы (единицы, меры) являются скоростью - первой производной какого-то прото-движения:
# $$ dx_\mathcal{h} = \frac{d H}{ d\chi } d\chi = \tilde{H} \ d\chi, \ dx_\mathcal{l} = \frac{d L}{ d\chi } d\chi = \tilde{L} \ d\chi \qquad (1.1) $$
# Проще говоря, мы динамизируем тензор пространства-времени через единую общую переменную, введя скорость интервала СТО $ ds = \tilde{S} \ d\chi $ аналогично ранее представленым прото-скоростям:
# $$ \tilde{S}^2 = \frac{ds^2}{d\chi^2} = \frac{g_{ij} dx^i dx^j}{d\chi^2} = g(\chi) = \begin{pmatrix} \tilde{H}^2 & 0 \\ 0 & -\tilde{L}^2  \end{pmatrix} = \tilde{H}^2 - \tilde{L}^2 \quad (1.2) $$
# Что равносильно:
# $$ \tilde{\mathcal{H}}^2 = \tilde{S}^2 + \tilde{L}^2  \qquad (1.3) $$
# С математической точки зрения можно сказать, что (1.3) просто утверждает существование параметра, по которому темпоральная компонента интервала может быть разложена как сумма двух проекций на перпендикулярные оси в евклидовом пространстве, то есть если представить, что время-пространство индуцировано изменением единого параметра, то величина скорости по данному параметру вдоль темпоральной координатной оси может быть представлена как сумма скоростей вдоль двух отдельных компонент - пространственной и вне-пространственной (наблюдаемой и ненаблюдаемой, внешней и внутренней).
# Проще говоря, (1.3) выглядит как формула сложения скоростей в евклидовом векторном пространстве. Предположим, что так и есть, но по какой-то причине при повороте "угла обзора" сохраняется не норма $ \tilde{H} $, а проекция на вне-пространственную $ \tilde{S} $.
#
# ## 2. Концепт потока
# Предположим, что слева в (1.3) - величина, являющаяся источником всей динамики времени-пространства __некоторого объекта__. Будем называть эту величину __потоком__, а векторное пространство (в математическом смысле, не в физическом), в котором поток существует - [__Хора__ (Платон)](https://en.wikipedia.org/wiki/Kh%C3%B4ra?utm_source=chatgpt.com).
# Геометрически мы определим два базисных вектора назвав их условно (__прото-время__, __прото-пространство__), не разделяя пространство, чтобы не усложнять: $ (\mathbf{e}_h, \, \mathbf{e}_l) $; получив в результате представление потока $\tilde{H} = \tilde{H} (\tilde{S}, \tilde{L})$ как вектора в данном базисе.
# Введём название и обозначение некоторой __прото-функции__, задающей характер потока объекта как вектор в обозначенном __прото-пространстве__:
# $$ H = H (\chi_n), \ H \in \mathbb{R}^n \qquad (2.1) $$
# И далее рассмотрим какими свойствами она должна обладать, чтобы подобрать её форму.
#
# ### 2.1. Скорость потока
# Мы стали обозначать скорость тильдой вместо точки или штриха, чтобы избежать возможной путаницы в будущем, потому что величина с точкой - это скорость по локальному времени объекта, со штрихом - по длине, а тильда - по прото-параметру:
# $$ [ \tilde{H} ], [ \tilde{S} ], [ \tilde{L} ]   = \left[ \frac{ \mathtt{прото-пространство} }{ \mathtt{прото-параметр} } \right] $$
# Будем называть её также __прото-скорость__.
#
# ### 2.2. Объект
# Любая ненулевая величина скорости потока ($ \tilde{H} \ne 0 $) будет называться __объектом__. Если объект производит в нашем восприятии собственную систему отсчёта, в которой он находится в покое:
# $$ \tilde{S} = \tilde{H} \qquad (2.2.1) $$
# то можно сказать, что весь поток объекта является ненаблюдаемым (для самого объекта) - внутренним. Будем говорить о таком объекте как о __сложном__ (__массивном__), в противопоставление объекту, который не может находится в покое:
# $$ \tilde{L} = \tilde{H} \qquad (2.2.2) $$
# и весь поток которого внешний. Будем называть его __простым__ объектом.
# Таким образом, сложным объектом на языке современной физики будет являться любое __событие__ в смысле СТО или череда таковых - мировая линия, а простым - вектор подпространства нулевого интервала, содержащий информацию о __событии__.
# В общем случае, объект без взаимодействий это постоянная величина количества прото-движения, которое может быть представлено вектором в пространстве прото-скоростей $ (\mathbf{e}_h, \, \mathbf{e}_l) $, которое удобно будет представить комплексным: $ \tilde{V} = e^{z}, z \in \mathbb{C}: \Re(\tilde{V}) = \tilde{S}; \ \Im(\tilde{V}) = \tilde{L}; \ |\tilde{V}| = \tilde{H} $.
# Из (2.2.1) и (2.2.2) совместно следует, что поток сложного объекта всегда движется вдоль реальной оси с той же прото-скоростью $ \tilde{H} $, с которой простые объекты движутся перпендикулярно ему - вдоль мнимой.
# В представлении униметрии мы предлагаем рассматривать сложный объект как совокупность множества элементарных замкнутых траекторий с проекциями на наблюдаемое пространство для реализации эффектов создаваемых полей в его окресности (гравитационное, электро-магнитное, сильное и слабое взаимодействия), что для моделирования эффектов ОТО может быть представлено гладко изменяющимся скалярным полем над прото-пространством, а для СТО - принято постоянным. Кажется, это всё, что пока можно постулировать на данном этапе.
# Кроме того, подобная конструкция позволит объяснить эффекты изменения геометрии тел при наличии скорости, например, просто как пересечение прото-образа (вероятно, полисферы) сложного объекта с подпространством простых объектов, которое зависит от состояния приёмника. В конце концов, если подпространство простых объектов всегда находится внутри множества пространств всех сложных объектов, то простой объект окажется свойством сложного.
# Эффекты СТО достигаются трансляцией точки в пространстве $ (\mathbf{e}_h, \, \mathbf{e}_l) $ вдоль мнимой оси (с сохранением реальной части - интервала). При таком преобразовании теряется ортогональность, и норма изменяется. Это и создаёт известное противоречие с привычным пониманием относительности - норма вектора $ |\tilde{V}| = \tilde{H} $ увеличится.
# Противоречие возникает оттого, что если объект А движется относительно объекта Б, то норма скорости потока А будет больше, но вместе с тем, объект Б движется в ИСО объекта А, где норма потока А должна быть меньше, чем норма потока Б. Эта неурядица с нормами наряду с эмпирически установленным постоянством скорости света привела к использованию здесь гиперболического инструментария.
# В предлагаемом концепте, очевидно, необходимо принять, что норма изменяется в части относительной скорости, но существует математический механизм, приводящий к выравниванию по вне-пространственной оси. С ним и с постоянстом скорости света разоберёмся далее.
#
# ### 2.3. Время и пространство
# Масштабирование времени скоростью потока можно задать по цепному правилу через нормирующий фактор:
# $$ dx_h = \tilde{H} \ d\chi = \frac{dx_h}{d\chi} \textcolor{blue}{ \frac{d\chi}{d\tau} } \ d\tau = \tilde{H} \textcolor{blue}{ \dot{\chi} } \ d\tau = \dot{H} d\tau = \mathtt{c} d\tau \qquad (2.3.1) $$
# Отсюда видно, что мы принимаем скорость потока по локальному времени константой скорости света $ \mathtt{c} $.
# Аналогично для пространственной части:
# $$ dx_l = \tilde{L} \ d\chi = \frac{dx_l}{d\chi} \textcolor{green}{ \frac{d\chi}{dl} } \ dl = \tilde{L} \textcolor{green}{ \chi' } \ dl = L' dl \qquad (2.3.2) $$
# Из равенства для светового нулевого интервала: $ dx_h = dx_l \Rightarrow \mathtt{c} = \tilde{L}' \frac{dl}{d\tau} $. Hесложно видеть, что при масштабировании темпоральной оси скоростью света пространственный масштаб всегда будет единичным $ \tilde{L}' = 1 $. Это удобно, но предположим, что у этого натурально возникающего удобства есть причина в виде единой прото-скорости масштабирующей нашу воспринимаемую реальность. Зафиксируем и вернёмся к этой мысли позже.
#
# ### 2.4. Скорость света
# Выразим интервал (1.2) представив обе координаты через прото-параметр:
# $$ ds^2 \ \hat{\mathbf{e}}_h^2 = \frac{\mathtt{c}^2}{ \dot{\chi}^2} d\chi^2 - \frac{1}{ \chi'^2 } d\chi^2 \ \hat{\mathbf{e}}_l^2 \qquad (2.4.1) $$
# Примая интервал равным нулю:
# $$ \mathtt{c} = \frac{\dot{\chi}}{ \chi' } = \frac{dl}{ d\tau } \ne f(\chi) \qquad (2.4.2) $$
# Откуда видно, что скорость света является параметром, связывающим движения по осям __вне зависисмости от значения прото-параметра__.
# Во-первых, если посмотреть на (2.4.2) следующим образом:
# $$ \mathtt{c} = \frac{\dot{\chi}}{ \chi' } = \left(\frac{d\chi}{d\tau} \right) \left[ \frac{dl}{ d\chi } \right] \sim (\nu) \ [\lambda] \qquad (2.4.3) $$
# То можно заметить сходство с характеристиками фотона _частота_ и _длина волны_, произведение которых даёт скорость света. Следовательно, далее будем исследовать фазу в качестве претендента на прото-параметр: $ \chi = \phi $.
# Во-вторых, из (2.4.1) и (2.4.2) следует:
# $$ ds^2 = \mathtt{c}^2 \left( \frac{d\chi^2}{ \dot{\chi}^2}  - \frac{d\chi^2}{ \dot{\chi}^2} \right) = 0, \forall \dot{\chi} \qquad (2.4.4) $$
# где решением для единичной частоты будет $ \tau = \chi $, значит в терминах фазы можно составить интервал для каждого отдельного фотона, где собственным временем фотона будет являться течение его фазы. Это в некотором смысле подтверждает идею о вторичности времени относительно фазы как средства измерить относительность произвольных циклов.
# Также важным наблюдением является факт попытки нормирования интервала фотона его частотой, однако в связи с отсутствием у фотона проекции на ось потока $ \mathbf{e}_l $, эта попытка реализуется лишь как линейное преобразование фазы фотона пропорционально изменению фазы потока, которая, фактически, выполняет роль времени сложного объекта:
# $$
# \frac{\chi_1}{\chi_0} = \frac{\tau_1}{\tau_0} \qquad (2.4.5)
# $$
# Можно сказать, что у фотона просто нет собственного течения по времени в нашем понимании последнего, поэтому он масштабируется только нашим ощущением времени сложного объекта. Такое восприятие несколько непривычно, но получается, что у фотона нет частоты - только некоторая величина фазы. Частота появляется только как отношение этой фазы к собственной фазе времени наблюдателя.
#
# ### 2.5. Поток сложного объекта
# Это ключевой пункт теории. Сложный объект существует в потоке, и является его частью. В отношении моделирования эффектов СТО важной является связь потока с гравитационными эффектами. Утверждая, что существует некоторый вектор $ \mathbf{e}_h $, ортогональный наблюдаемому пространству, мы вводим нормаль, предполагая, что совокупный гравитационный фон формирует течение, которое задаёт данный базисный вектор, а наблюдаемое пространство - три степени свободы, которые ему ортогональны. Именно в этом порядке.
# Отсюда следует существование локального фонового вектора $ \vec{H}_0 = \tilde{H} (\mathbf{e}_h) $, задающего движение части потока в точке находждения сложного объекта, которая не является его составной частью, а приходит извне (например, для искусственных спутников Земли основная часть фонового потока создаётся Землёй); и собственного вектора потока $ \vec{h} = \tilde{h}(\mathbf{e}_h, \mathbf{e}_l) $, который создаётся движением самого объекта.
# Далее мы в первую очередь рассматриваем случай, когда фоновый вектор относительно слаб $ \tilde{h} >> \tilde{H}_0 $, однако необходим, чтобы утверждать наличие локальной системы отсчёта, где течение времени - собственной фазы объекта - будет максимальным: $ \vec{h} \, || \, \vec{H}_0 $; а отклонение от этой нормали даст видимое перемещение в наблюдаемом пространстве вместе с относительным замедлением времени.
# Здесь мы можем пойти двумя путями для формализации механизма преобразований, соответствующих возникновению пространственного отклонения потока.
# 1. Прямой. Мы знаем, что в результате преобразования прото-скоростей:
# $$ \tilde{\mathcal{H}}^2 = \tilde{S}^2 + \tilde{L}^2 \overset{\cdot \dot{\chi}^2}{\Longrightarrow} \dot{\mathcal{H}}^2 = \dot{S}^2 + \dot{L}^2 $$
# Происходит переход нормы от $ \tilde{\mathcal{H}} $ к норме $ \dot{S} $. Тогда единственной возможнотью для реализации этого перехода является, очевидно, нормирующий фактор - отношение фазы той системы, из которой переходим, к той, в которую переходим. Чтобы сохранение евклидовой нормы выглядело сохранением псевдо-евклидовой нормы, он должен быть отношением прото-скоростей:
# $$ \dot{\chi} = \frac{\chi_{\mathtt{obs.}}}{\chi_{\tau}} = \frac{\tilde{H}}{\tilde{S}} = \frac{1}{\sqrt{1-\frac{\tilde{L}^2}{\tilde{H}^2}}} = \frac{1}{\sqrt{1-\frac{V^2}{\mathbf{c}^2}}} = \gamma \qquad (2.5.1) $$
# Учитывая, что время наблюдателя привязано к частоте некоторого воспроизводимого процесса, и в нашем представлении является просто эталонной фазой, нормализующий фактор является ничем иным как частотой. Однако мы считаем, что изменение характеристик пространственного движения объекта влечёт объективное изменение эталонной фазы - по отношению к фазе неподвижного объекта, например, и следовательно изменение течения локального времени.
# 2. Обратный. Сохранение полной фазы сложного объекта (равно как и для суммы его частей) будет:
# $$ \chi_{\mathtt{obs.}}^2 = \chi_{\tau}^2 + \chi_l^2 \Rightarrow \frac{\chi_{\mathtt{obs.}}}{\chi_{\tau}} = \frac{1}{\sqrt{1 - \frac{\chi_l^2}{\chi_{\mathtt{obs.}}^2}}} = \gamma  \qquad (2.5.2) $$
# Откуда следует аналогичное отношение.
#
# В любом из представлений Лоренц-фактор возникает не как самодостаточный постулируемый конструкт, а как отношение фаз. При этом реального "поворота" объекта, вероятно, не происходит - иначе в форме интервала возникали бы билинейные компоненты. Данный аппарат скорее лишь обобщённо демонстрирует предполагаемую внутреннюю совокупную зависимость фазовых изменений сложного объекта.
# Резюмируя выше написанное, можно утверждать, что гиперболическое преобразование специальной теории относительности в терминах времени-пространства может быть представлено поворотом в евклидовом фазовом пространстве.
#
# Покажем на простом примере. Пусть собственная фаза Алисы, находящейся на поверхности Земли, $ \chi_A = 1 \ [\mathtt{рад}] $. Боб летит на Альфу Центавра за Джумбо-багетом. Его скорость в ИСО Алисы $ \beta = V / \mathtt{c} = 0.5 [] $, что в единицах фазы Алисы $ \tilde{\beta} = \chi_A \cdot \beta = 1 \cdot 0.5 = 0.5 \ [\mathtt{рад}] $. Фаза Боба будет корнем из евклидовой разности частоты Алисы и своей скорости в её восприятии: $ \chi_B = \sqrt{\chi_A^2 - \tilde{\beta}^2} = \sqrt{1 - 0.25} = 0.866 \ [\mathtt{рад.}] $, что значит его время течёт в 0,866 раз медленнее.
# <div class="alert alert-block alert-info"> <b>Примечание.</b> Если принимать фазу Алисы отличной от единицы, относительную скорость Боба пришлось бы <i>перенормировать в единицах фазы Алисы</i> - за большую фазу он пройдёт больше пространства: \(\tilde{\beta}=\chi_A\,\beta\). Тогда \(\chi_B=\sqrt{\chi_A^2-\tilde{\beta}^2} =\chi_A\sqrt{1-\beta^2}\), и, следовательно, \(\chi_B/\chi_A=\sqrt{1-\beta^2}=1/\gamma\). С единицей всё арифметически проще.
# </div>
#
# ### 2.6. Парадокс близнецов
# В представлении униметрии парадокс близнецов разрешается через наличие движения относительно гравитирующих объектов. Близнец менее подвижный в гравитационном поле состарится больше - его частота выше, так как он не тратит фазу на движение поперёк потока.
#
# ### 2.7. Фазовая разность излучения
#
# #### 2.7.1. Определения
#
# - $\phi_s$ — фаза излучения в системе источника
# - $\phi_0$ — фаза, измеренная наблюдателем
# - $\omega_s = \frac{d\phi_s}{d\tau_s}$ — частота источника
# - $\omega_0 = \frac{d\phi_0}{d\tau_0}$ — наблюдаемая частота
# - $\beta = V / \mathtt{c}$, $\gamma = 1/\sqrt{1-\beta^2}$
#
# Продольный релятивистский Доплер:
#
# $$
# r \equiv \frac{\omega_0}{\omega_s} = \sqrt{\frac{1-\beta}{1+\beta}}
# $$
#
# #### 2.7.2. Связь фазы и частоты
#
# Частота — это изменение фазы по собственному времени:
#
# $$
# \omega_s = \frac{d\phi_s}{d\tau_s}, \quad \omega_0 = \frac{d\phi_0}{d\tau_0}
# $$
#
# Тогда:
#
# $$
# r = \frac{\omega_0}{\omega_s} = \frac{d\phi_0 / d\tau_0}{d\phi_s / d\tau_s} = \frac{d\phi_0}{d\phi_s} \cdot \frac{d\tau_s}{d\tau_0}
# $$
#
# С учётом релятивистского замедления времени:
#
# $$
# \frac{d\tau_s}{d\tau_0} = \gamma \quad \Rightarrow \quad \frac{d\phi_0}{d\phi_s} = \frac{r}{\gamma}
# $$
#
# #### 2.7.3. Подставим выражения
#
# $$
# \frac{d\phi_0}{d\phi_s} = \frac{ \sqrt{\frac{1-\beta}{1+\beta}} }{ 1/\sqrt{1-\beta^2} } = \sqrt{\frac{1-\beta}{1+\beta}} \cdot \sqrt{1-\beta^2} = 1 - \beta
# $$
#
# #### 2.7.4. Формула фазовой разности
#
# Определим фазовую разность как
#
# $$
# \Delta \phi = \phi_s - \phi_0
# $$
#
# Тогда при малых интервалах:
#
# $$
# d\Delta \phi = d\phi_s - d\phi_0 = d\phi_s - (1-\beta)d\phi_s = \beta \, d\phi_s
# $$
#
# Или в виде со "скоростью":
#
# $$
#  \frac{ \Delta \phi }{\phi_s} = \frac{ V }{\mathtt{c}} \qquad (2.7)
# $$
#
# #### 2.7.5. Интерпретация
#
# - $\beta = 0 \Rightarrow d\Delta \phi = 0$ — фаза инвариантна
# - $\beta \neq 0$ — относительное движение приводит к изменению фазы пропорционально $\beta$
# - $ V < 0 $ — объект движется к наблюдателю, фаза увеличивается
# - $ V > 0 $ — объект движется от наблюдателя, фаза уменьшается
#
# ### 2.7.6. Фазовый нормализующий фактор
# Мы предположили, что фотон не имеет частоты, которая возникает только как результат его восприятия сложным объектом. Тогда можем предположить, что полное релятивистское отношение частот является преобразованием фазы самого объекта. Тогда здесь возникает противоречие:
# $$
#     \dot{\chi} = \frac{\chi_{\mathtt{obs.}}}{\chi_{\tau}} = \frac{\tilde{H}}{\tilde{S}} = \frac{\tilde{H}}{\tilde{H} \, \cos \zeta} = \frac{1}{\cos \zeta}
# $$
# где параметризирующий угол цета связан со скоростным поворотом следующим образом: $ \sin \zeta = \beta $, значит:
# $$
#     \dot{\chi} = \frac{1}{\cos \zeta}
# $$
#
#
# Следовательно, далее мы будем исходить из (1) фундаментальности прото-параметра и вторичности времени и пространства и (2) геометрической интерпретации времени.
# Первое означает, что время-пространство создаётся изменением в отношениях характеристик объектов. Второе - темпоральную ось можно представить замкнутой осью варьируемой величины (прото-скорость), тогда изменение течения времени будет происходить в результате переноса одной и той же прото-длины в системы отсчёта с меняющийся геометрической структурой.
# Предположим, что прото-функция может быть описана как бесконечно малый элемент длины в полярных координатах:
# $$ dH^2 = dR^2 + R^2 d\phi^2 \iff dH^2 = d\tilde{H}^2 + \tilde{H}^2 d \chi^2 \qquad (2.5.1) $$
# Принимая, что правая часть (1.3) состоит из "внутренней" $ \tilde{S} $ и "внешней" $ \tilde{L} $ динамики, разложим угловую компоненту по двум осям $ d\chi^2 = d\chi_s^2 + d\chi_l^2 $, и подставим в (2.5.1):
# $$ dH^2 = dR^2 + R^2 d\phi_s^2 + R^2 d\phi_l^2 \iff dH^2 = d\tilde{H}^2 + \tilde{H}^2 d \chi_s^2 + \tilde{H}^2 d \chi_l^2 \qquad (2.5.2) $$
# Мы получили тот же объект, но с альтерацией по углу обзора, с естественным сохранением нормы при поворотах (ортогональных преобразованиях).
# Как мы заметили в 2.3 скорость потока должна быть единой для обеспечения правильного проецирования Хоры в метрику Минковского, что вполне уместно геометрически представляется как сохранение радиуса в (2.5.2). Теперь мы можем разделить эффекты, на возникающие при постоянстве радиуса и варьировании полной фазы по внутренней - эффекты СТО, и прочие вариации - эффекты ОТО.
# Первый вариант выводится из условия сохранения полной фазы весьма несложно. Для моделирования эффектов СТО полную фазу необходимо варьировать по темпоральной оси без изменения прото-скоростей:
# $$ ] \ dR = 0: \quad dH^2 = R^2 d\phi^2 = R^2 d\phi_s^2 + R^2 d\phi_l^2 \ \iff \ \frac{d\chi}{d\chi_s} = \left( 1 - \frac{d\chi_l^2}{d\chi^2} \right)^{-1/2} \sim \gamma \qquad (2.5.3) $$
# Что читается как наличие относительной пространственной фазы объекта ведёт к изменению восприятия его темпоральной фазы. Это прямой аналог гамма-фактора: у объекта в покое течение времени будет соответствовать полной фазе, а у движущегося относительно него часть фазы будет "использоваться" в движении, за счёт чего движение по темпоральной оси будет замедленно (фаза меньше $ \Rightarrow $ частота ниже $ \Rightarrow $ процессы медленнее).
# <details>
# <summary>Вывод гамма-фактора.</summary>
# Из (2.3.1) и (2.3.2) (принимая $ \tilde{H} = R $):
# $$ d\chi_{s0} = \frac{\mathtt{c} d\tau_0}{ R } = d\chi, \quad d\chi_{s1} = \frac{\mathtt{c} d\tau_1}{ R }, \ d\chi_{l1} = \frac{dl}{R}:  $$
# $$ \frac{d\chi_{s1}^2}{d\chi_{s0}^2} = 1 - \frac{d\chi_{l1}^2}{d\chi_{s0}^2} \iff \gamma = \frac{d\tau_0}{d\tau_1} = \left( 1 - \frac{v^2}{c^2} \right)^{-1/2}  $$
# </details>
#
# ### 2.6. Единицы измерения
# Из (2.3.1) и (2.4.1) видно, что прото-скорость фотона это просто его длина волны. Отсюда, наконец, можно связать единицы измерения длины и времени с прото-пространством:
# $$ \begin{matrix} \left[ \frac{ \mathtt{прото-пространство} }{ \mathtt{фаза} } \right] \ \hat{\mathbf{e}}_{L} = \frac{1}{2\pi} \left[ \frac{\mathtt{длина}}{\mathtt{фаза}} \right] & \Rightarrow & 2 \pi \ [\mathtt{прото-пространство}] \ \hat{\mathbf{e}}_{L} = [\mathtt{длина}] & \Rightarrow \\ 2 \pi \  [\mathtt{прото-пространство}] \ \hat{\mathbf{e}}_{S} = [\mathtt{длина}] & \Rightarrow & \frac{2 \pi}{ \mathtt{c}} \  [\mathtt{прото-пространство}] \ \hat{\mathbf{e}}_{S} = [\mathtt{время}] \end{matrix} \qquad (2.6.1)  $$
# Изначально требовалось выразить всю динамику объектов через единый прото-параметр - фазу. Однако, в результате для преобразования прото-пространства в обычное пространство фаза не требуется, значит, раз пространственные характеристики не являются функциями прото-параметра, то можно допустить, что пространство пусто - не взаимодействует с объектами и не является объектом физики - чисто математический объект. Равно, как и для преобразования времени в длину фаза не требуется, потому что отношение времени и пространства фиксировано через константу скорости света, которая в представлении униметрии является прото-скоростью реализации динамики объектов (скоростью полной фазы), приведённой к локальным единицам времени.
#
#
#
# ### 2.8. Взаимодействие фаз
# Взглянем на (2.7) как на взаимодействие двух ортогональных угловых компонент - сложного из (2.5.3) и простого объектов:
# $$
# d\chi \, ( d\phi_s - d\phi_0 ) = d\chi_l \, d\phi_s \iff d\chi \, d\phi_0 = ( d\chi  - d\chi_l ) \, d\phi_s
# $$
# которое читается как наличие пространственной компоненты фазы сложного объекта изменяет фазу простого объекта.
# Отсюда предположим, что прото-функция должна отражать взаимодействие фаз.
#
# ### 2.8.1. Кватернион излучения
# Мы показали, что эффект СТО воспроизводим в терминах униметрии, но задачей перехода к нативным метрическим единицам было упростить всё, а не наоборот. Поэтому попытаемся теперь взглянуть на мир через призму униметрии - фазу - напрямую. Удобно будет это сделать на примере.
# Положим на расстоянии $ D [m] $ от приёмника находится источник излучения. Примем декартову 3-ёхмерную систему координат с приёмником в начале, тогда произвольное направление на объект может быть задано единичным мнимым кватернионом, скажем, $ \mathbf{ u } \in \mathbb{H}: |\mathbf{u}| = 1, \Re (\mathbf{u}) = 0 $.
# Представим, что приняли с этого направления фотон с длиной волны $  \tilde{H}_1 \equiv \lambda_1  $ равной прото-скорости фотона. Если записать кватернион в таком виде:
# $$
# \mathbf{p} = \cos \Phi_1 + \mathbf{u} \sin \Phi_1 = e^{\Phi_1 \mathbf{u}}, \quad \Phi_1 = \frac{2 \pi \ D}{ \lambda_1 }
# $$
# то получим некоторый кватернион "положения", в котором роль расстояния выполняет фаза.
# Однако, в таком виде фотону каждой длины волны будет соответствовать особый кватернион, что неудобно, поэтому дополнительно нормируем его длиной волны $ \lambda_1 / 2\pi = e^{h_1} $, тогда получится:
# $$
# \mathbf{P} = \frac{\lambda_1}{2\pi} \ \mathbf{p} = \frac{\lambda_1}{2\pi} \ e^{\Phi_1 \mathbf{u}} = e^{h_1 + \Phi_1 \mathbf{u}} = e^{\mathbf{z}_1}: \quad \int_0^{\Phi_1}{ \left| \frac{ d\mathbf{Q} }{ d\Phi } \right| d\Phi  } = \int_0^{\Phi_1}{ \frac{\lambda_1}{2\pi} d\Phi  } = \frac{\lambda_1 }{2\pi} \Phi_1 = \frac{\lambda_1 }{2\pi} \cdot \frac{2 \pi \ D}{ \lambda_1 } = D, \forall \lambda_1
# $$
# что даст универсальный кватернион, который можно подстраивать по нужной длине волны, получая соответствующую ей фазу, но для любого случая длина траектории точки на 3-сфере по изменению фазы сохраняется постоянной и равна расстоянию в привычном понимании.
# Используя эту функцию в качестве нормы на пространстве кватернионов можем ввести ввести отображение:
# $$
# \mathbf{Q} \mapsto \vec{D}
# $$
# извлекающее дистанцию как:
# $$
# \left| \vec{D} \right| = \int_0^{\Phi_1}{ \left| \frac{ d\mathbf{Q} }{ d\Phi } \right| d\Phi  } = D
# $$
# Иначе говоря, кватернион положения после нормировки напрямую задаёт наблюдаемую дистанцию и направление на объект.
# Очевидно, тогда верно:
# $$
# \tilde{H} = \frac{d\vec{D}}{ d\Phi } = \left| \frac{ d\mathbf{Q} }{ d\Phi } \right|
# $$
# Посмотрим на разложение квадратичной формы данного кватерниона на билинейные отображения:
# $$
# \tilde{H}^2 = \left| \frac{ d\mathbf{Q} }{ d\Phi } \right|^2 = \frac{\lambda_1^2}{4 \pi^2} (-\sin \Phi_1 + \mathbf{u} \cos \Phi_1)^2
# $$
#
# ### 2.8.2. Кватернион сложного объекта
# Будем называть его __генератор__. Мы уже фактически задали его ранее в 2.2:
# $$
# \mathbf{G} = 1 \cdot \mathbf{g} = \cos \chi_1 + \mathbf{v} \sin \chi_1, \quad \sin \chi_1 = \beta
# $$
# Прото-скорость будет:
# $$
# \breve{H}^2 = \left| \frac{ d\mathbf{G} }{ d\chi } \right|^2 = (-\sin \chi_1 + \mathbf{u} \cos \chi_1)^2 = -\cos 2\chi_1 - \mathbf{u} \sin 2\chi_1 = \breve{S}^2 + \breve{L}^2
# $$
# Поэтому, в числе прочего, мы использовали здесь кватернионы - прото-скорость распадается на нужные части:
#
# Разложим по билинейным отображениям:
#
#
# ### 2.8.3. Прото-функция
# Зададим прото-функцию как сумму билинейных отображений:
# $$
# dH = \frac{\mathbf{G} \circ \mathbf{P} + \mathbf{P} \circ \mathbf{G}}{2}
# $$

# %%
Сложность зависит от скорости потока. И влияет на гравитацию. То есть если скорость потока деградирует в масштабах вселенной меняется значение массы - значение гравитации меняется.
Для того, чтобы найти переход к терминам массы и энергии, интересным будет рассмотреть с тех же позиций униметрии уравнения полной энергии объектов:
Масса не является функцией фазы - в уравнении полной энергии по фазе гамма-фактором компенсируется только время. То есть масса - внутреннее свойство сложных обхектов, которое зависит только от их конфигурации, но не от скорости реализации.
Каждый фотон по собственному времени несёт одинаковое количество энергии - постоянную Планка. Фотон - явление распространения информации о событии по внешним "нитям" сложных объектов. 

Наблюдаемый внутренний радиус может меняться под углом наблюдения, что сохранит норму. Но представить это геометрически?!
Потому что меняется не радиус, а частота.
Итак, примерно:
Радус (скорость) потока - характеристика обстоятельств объекта (создаваемых массой).
Частота - характеристика объекта, зависящая от обстоятельств объекта-наблюдателя.
$$ \sim \nu = \frac{ d\phi }{ d\tau} = \frac{ \mathtt{c} }{ \lambda } $$

Течение времени обратно пропорционально радиусу и прямо пропорционально скорости фазы. Положим, элемент со скоростью фазы v движется в потоке радиуса R. Его собственное время оборота будет равно $ T = 2 \pi R / v $ собственное время на радиусе R вопринимается как период частоты 1 [Hz], то есть 
если представить, что свет движется в пространстве всегда со скоростью фазы, то различие радиусов (прото-скоростей) - это различие фактического относительного расстояния, проходимого светом. Больше прото-скорость - больше расстояние.

# %% [markdown]
# ### 2.7. Качественное описание
# В результате описанных рассуждений центральным звеном теории становится сложный объект - масса. Фактически, униметрия предлагает перенести всю сложность тензорной гиперболической реализации пространства-времени на сложный объект, вывернув динамику наизнанку, предлагая ряд возможных объяснений некоторых явлений:
# 0. Принцип неопределённости.
# 1. Униметрия предполагает двойственность внутренних свойств фундаментальных частиц (состояние спина) и их конфигураций вследствие допустимости двойного направления по оси "времени".
# 2. Представляя все гравитирющие объекты множеством структурно объединённых циклических сущностей, униметрия включает вакуум квантовой теории поля в состав макро-объекта "Вселенная" и представляет неопределённость волновой функции квантовой механики лишь эффектом постоянного воздействия со стороны вакуума, которое на большем масштабе пространства и/или времени может представляться статистически скомпенсированным волновым эффектом, на малом, однако, допускать аномалии, в том числе, например, по причине относительного перемещения масс в составе гравитирующего объекта.
# 3. Представление эффекта квантовой запутанности проекцией одного и того же потока на наблюдаемое пространство можно попробовать объяснить нарушение неравенств Белла через нелокальное взаимодействие проекций, однако, пока не ясно, что д
# 4.  недостаточным знанием наблюдателя об исходных данных и нарушением принципа локальности (близкодействия), в его современном понимании, являясь в первом приближении детерминистической теорией нелокальных скрытых параметров, так как в предлагаемой парадигме каждая наблюдаемая сущность постоянно подвергается воздействию со стороны вакуума, которое на большем масштабе пространства и/или времени является статистически скомпенсированным, однако, на малом может допускать аномалии, в том числе по причине относительного перемещения масс в составе гравитирующего объекта.
# Во-вторых,
#
#
# ## 3. Простой объект
# Простой объект (фотон) движется только по внешней оси Хоры, а сложный — имеет проекцию на внутреннюю: частицы сложного объекта должны иметь проекции на внешние оси для формирования наблюдаемого образа объекта. Вместе с тем, в зависимости от фазовых характеристик наблюдателя внешний образ создаваемый фотонами будет меняться. Можно предположить, что невидимый на нашем уровне восприятия образ обеспечивает эффект гравитации - скорость потока в точке пространства является скоростью течения фаз объектов, что влияет на их временные характеристики.
# Иначе говоря, фотоны формируют наблюдаемое 3-мерное пространство, однако его характеристики зависят от самого объекта-приёмника, потому что и фотон, и приёмник связаны изменением единого фактора - скоростью потока.
# Фотон имеет собственную прото-скорость, равную его длине волны. Масштаб восприятия фотона приёмником задаётся отношением их прото-скоростей.
#
# ### 3.1. Аналитическое представление
# Будем называть простой объект _фотоном_ и характеризовать его количественно прото-скоростью $ \tilde{v}_p = dx_p / d\chi $, что с использованием (2.3.1) будет:
# $$ \textcolor{blue}{ \dot{\chi}_p } = \left(\frac{d\chi_p}{d\tau_p} \right) = (\nu_p) =  \frac{ \mathtt{c} }{ \tilde{H} } \overset{\tilde{H} = \tilde{v}_p}{\implies} (\nu_p) =  \frac{ \mathtt{c} }{ \tilde{v}_p } = \frac{ dx_h }{ dx_p } \frac{ d \chi_p }{ d\tau_p } \implies dx_h = dx_p = dx_l; \ [\lambda_p] = \tilde{v}_p \qquad (3.1.1) $$
# И при условии $ \tau = \chi \Rightarrow (\nu_p) = 1 $ из (2.4.3) даст собственный интервал фотона (задающий время, по которому скорость фотона в прото-пространстве равна скорости света), необходимо лишь формально разделить оси.
# Такой интервал задаёт прото-длину, на которую может успеть сместиться сложный объект по внутренней оси пока фотон смещается по внешней, равную смещению фотона, __если прото-скорости объекта и фотона равны__. Как если бы фотон принимался равноценным фотоном, но движущимся "ненаблюдаемо" (то есть уже массивным объектом).
# Также здесь видно, что прото-скорость фотона это просто его длина волны. Отсюда, наконец, можно связать единицы измерения длины с прото-пространством:
#
# А время, получается, должно бы являться функцией скорости фазы, но так как наблюдение и времени, и пространства зависят от одного параметра, то движение по темпоральной оси гораздо проще выразить через константу скорости света.
# Теперь мы можем переписать интервал (2.3.3) для фотона с использованием новых терминов:
# $$ ds^2 = \left(  \lambda_p^2 \hat{\mathbf{e}}_{S}^2 - \nu_p^2 \hat{\mathbf{e}}_{L}^2 \right) \ d\chi^2 = \mathtt{c}^2  \left( \nu_p^{-2} \hat{\mathbf{e}}_{S}^2 - \lambda_p^{-2} \hat{\mathbf{e}}_{L}^2 \right) \ d\chi^2 \qquad (3.1.3) $$
# Однако первый компонент не является частью активности фотона, он лишь эквивалент его движения в пространственной части, и по сути вторичен, когда сам вектор несёт информацию о частоте или длине волны.
# В остальном это весьма и весьма вычурная и нежизнеспособная модель, потому что такой массивный объект получился бы, вероятно, нестабилным, как минимум, ввиду трёхмерности наблюдаемого пространства, поэтому введём произвольный сложный объект-наблюдатель (приёмник), обстоятельства приёма которого характеризуются прото-скоростью только по ненаблюдаемой оси (массивный объект, находящийся в покое в собственной ИСО): $ \tilde{H}_o = \frac{ dx_h }{ d\chi } $. Тогда его частота относительно себя будет также единичной, порождая собственное локальное восприятие времени:
# $$ \textcolor{blue}{ \dot{\chi}_o } = \left(\frac{d\chi}{d\tau_o} \right) = (\nu_o) = \frac{ \mathtt{c} }{ \tilde{H} } \overset{\tilde{H} = \tilde{H}_o}{\implies} (\nu_o) = \frac{ \mathtt{c} }{ \tilde{H}_o } = \frac{ dx_h }{ dx_o } \frac{ d \chi }{ d\tau_o } \implies dx_h = dx_o \qquad (3.1.4) $$
# Однако, частота фотона $ p $ в восприятии объекта $ o $ будет просто:
# $$ \mathtt{c} =  \nu_o \ \lambda_o = \nu_p \ \lambda_p \ \Rightarrow \ (\nu_{p\rightarrow o}) |_{\lambda_o = 1} = \frac{\mathtt{c}}{ \lambda_p } = \frac{\mathtt{c}}{ \tilde{v}_p } \qquad (3.5) $$
# Грубо говоря, собственная прото-скорость $ \tilde{H}_o = \lambda_o $ сложного объекта масштабирует принимаемый фотон своим течением фазы. Следовательно, область применимости специальной теории относительности в терминах униметрии - объекты одинаковой собственной фазовой скорости потока при наличии взаимной скорости в наблюдаемом пространстве.
#
# ### 3.2. Геометрическое представление
# Естественно будет представить фазу углом, что в совокупности с трёхмерностью наблюдаемого пространства даёт 3-сферу некоторого радиуса. Причём если принять образ прото-функции $ H = R \phi $, то  радиус будет прото-скоростью:
# $$ \tilde{H} = \frac{dH}{d\phi} = R \qquad (3.2.1) $$
# Тогда представим прото-функцию через произвольное перемещение в радиальных координатах:
# $$ dH^2 = dR^2 + R^2 d\phi \ \Rightarrow \ \breve{H}^2 = \frac{dH^2}{dR^2} = \left( 1 - \frac{ R^2 d\phi^2 }{ dH^2 } \right)^{-1} = \left( 1 - \frac{ R^2 \dot{\phi}^2 }{ \dot{H}^2 } \right)^{-1} \qquad (3.2.2) $$
# Мы ранее в (2.3.1) уже приняли изменение прото-функции по времени скоростью света, осталось заметить, что наличие фазовой скорости в таком представлении является не чем иным, как перемещением в наблюдаемом пространстве, а в данном контексте, перемещением на 3-сфере, совершаемом за некоторое локальное время, тогда очевидно производная прото-функции по радиусу даст гамма-фактор:
# $$ \breve{H}^2 = \frac{dH^2}{dR^2} = \left( 1 - \frac{ R^2 \dot{\phi}^2 }{ \dot{H}^2 } \right)^{-1} \sim \left( 1 - \frac{ V^2 }{ \mathtt{c}^2 } \right)^{-1} = \gamma^2 \qquad (3.2.3) $$
# И не повлияет на истинность предыдущих умозаключений по фазе ввиду принятого ранее условия относительной неизменности прото-скорости - радиуса. Иначе говоря, (3.2.2) даёт (3.2.1) при $ R = \mathtt{const} $.
# Наличие фазовой скорости объекта изменяет радиальную прото-скорость при условии сохранения полного количества движения. Можно сказать, что внешне-пространственное движение отнимает часть движения внутри-пространственного.
# Получилось неплохо, значит, во-первых, у нас есть второй прото-параметр $ \chi_2 = R $, а во-вторых, если запишем выражение полного количества движения в Хоре:
# $$ dH^2 = \frac{\partial H^2}{\partial R^2} dR^2 + \frac{\partial H^2}{\partial \phi^2} d\phi^2 = \breve{H}^2 dR^2 + \tilde{H}^2 d\phi^2 = \frac{dH^2}{d\tau^2} d\tau^2 = \mathtt{c}^2 d\tau^2 \qquad (3.2.4) $$
# И покажем его в виде соответствующем современному интервалу:
# $$ \breve{H}^2 dR^2 = \mathtt{c}^2 d\tau^2 - \tilde{H}^2 d\phi^2 \sim ds^2 = \mathtt{c}^2 d\tau^2 - dl^2 \qquad (3.2.5) $$
# То получится, что радиальное движение объекта представлет внутреннее, ненаблюдаемое движение объекта, формирующее его собственную циклическую структуру, которая влияет на восприятие времени. Однако происходит это иначе, чем в фазовой части. Характер связи между радиусом и локальным временем таков:
# $$ d\phi_1 > d\phi_0 \iff \ d\tau_1 < d\tau_0, \ \ dR_1 > dR_0 \iff \ d\tau_1 > d\tau_0 \qquad (3.2.6) $$
# Если фаза была обратна локальному времени, то радиус - пропорционален: чем больше радиус, тем медленнее происходят идентичные процессы (больше дифференциал времени), и из подобия (3.2.3) можно попробовать утверждать просто $ R = k \tau , \ k \in \mathbb{R} $.
# Тогда отношение радиусов (прото-скоростей) есть отношение времён:
# $$ \frac{R_0}{R_1} = \frac{\tau_0}{\tau_1} = \frac{\breve{H}_1}{\breve{H}_0} \qquad (3.2.7) $$
# Дальше, можем также связать фазовую и радиальную производные прото-функции через скорость света и выразить радиальную производную:
# $$ dx_h = \tilde{H} \ \dot{\phi} \ d\tau = \breve{H} \ \dot{R} \ d\tau = \mathtt{c} \ d\tau \quad \Rightarrow \quad \dot{R} = \frac{\tilde{H}}{\breve{H}} \dot{\phi} \qquad (3.2.8)  $$
# Значит, в собственной системе отсчёта с единичной частотой $ \nu = \dot{\phi} = 1 $ радиальная нормировка аналогичного объекта относительной пространственной скорости ($ R d \Delta(\phi) = 0 $) можно представить так:
# $$ \dot{R} = (\tilde{H}) \left[ \frac{1}{\breve{H}} \right] \sim  \ \mathtt{???} \qquad (3.2.9) $$
# Остановимся пока на этом.
#
# ### 3.3. Частота
# Представим, что некий объект 0 покоится в пространстве, а другой - объект 1 - находится от первого на расстоянии $ \Phi $ (фаза), движется относительно него с фазой $ d\phi $ и эмитирует фотоны в направлении покоящегося объекта с длиной волны (прото-скоростью) $ v_p $ и периодичностью $ T = \frac{v_p}{\mathtt{c}} $ (период эмиссии для удобства равен периоду фотона). Запишем в терминах униметрии.
# Частота первого эмитированного фотона в начальный момент по времени объекта 1:
# $$ \nu_p = \frac{\mathtt{c}}{v_p} $$
#
# Фазы объектов будут зависеть от выбора нулевой фазы:
# $$ d\phi = d\phi_1 - d\phi_0 = \Bigg\{ \begin{matrix} d\phi_1, & d\phi_0 = 0, \\ -d\phi_0, & d\phi_1 = 0  \end{matrix}$$
#
# Чтобы преодолеть фазу $ \Phi $, ему потребуется
#
# ### 3.4. Квантование
# Представить фазу внутреннего движения радиусом в 3.2 было удобно с чисто человеческой точки зрения - сферическая форма даёт некоторую опору в понимании, однако теперь необходимо представить, что радиус 3-сферы - тоже замкнутый контур.
#
# ## 4. Сложный объект
# Из предыдущих рассуждений следует, что сложный объект это прежде всего поток, направленный вдоль темпоральной оси, и характеризуемый некоторой прото-скоростью. Вместе с тем, эффект гравитационного воздействия на фотон и, вероятно, другие сложные объекты можно было бы получить введя внешне-пространственные проекции прото-векторов частиц, составляющих сложный объект. Предположим, что эти частицы (1) фотоно-подобны, но иначе геометрически ориентированы, а также (2) имеют свойство формировать устойчивые конфигурации.
# Считая внешне-пространственные оси равноправными, логично было бы наложить некое требование симметрии в сечениях $ (x_0,x_1), (x_0,x_2), (x_0,x_3) $, что даёт кратное трём количество сущностей для формирования устойчивой во времени структуры, что соответствует известным законам квантовой хромодинамики.
#
# ### 4.1. Фаза времени (сложного объекта)
# Представим, что существуют два количественно разных сложных объекта: $ H_0 = k H_1, \ k > 1 $. В собственных системах, где они находятся в покое, их течение времени будет отличаться прямо пропорционально их количеству прото-движения:
# $$ dH_0 = \mathtt{c} \tau_0 , \ dH_1 = \mathtt{c} \tau_1, \ dH_0 = k dH_1 \Rightarrow d\tau_0 = k d\tau_1 \qquad (4.1.1) $$
# Что означает, что у большего объекта время течёт медленнее в k раз.
#
#
# \sqrt{ \left(\frac{\partial H}{\partial \chi_s} \chi_s \right)^2 + \left( \frac{\partial H}{\partial \chi_l} \chi_l \right)^2 }, \ H \in \mathbb{R}^n
#
#
# :
# $$ dH^2 = \breve{H}^2 d\phi_\tau^2 + \tilde{H}^2 d\phi_l^2 = \frac{dH^2}{d\tau^2} d\tau^2 = \mathtt{c}^2 d\tau^2 \qquad (4.1.1) $$
# Это уже 4-сфера, но мы утрируем её за счёт невовлечения незатрагиваемых осей пространства. Остаётся просто окружность, где по мнимой оси развёрнута скорость внешней фазы, а по вещественной - внутренней (времени). Тогда отношение их прото-скоростей можно снова параметрировать углом, а из постоянства полного количества протодвижения объекта выводятся следующие эффекты.
# Ранее мы уже получили гамма-фактор в качестве зависимости изменения потока по времени наблюдателя от изменения внешней фазы:
# $$ \gamma = \frac{dH}{\breve{H} d\phi_\tau} = \left( 1 - \frac{\tilde{H}^2 d\phi_l^2}{\mathtt{c}^2 d\tau^2} \right)^{-1/2} = \left( 1 - \frac{V^2}{\mathtt{c}^2} \right)^{-1/2} \qquad (4.1.2) $$
# Теперь можем получить закон изменения потока в наблюдаемом пространстве сложного объекта:
# $$ \tilde{H}^2 d\phi_l^2 = \mathtt{c}^2 d\tau^2 \left( 1- \frac{\breve{H}^2 d\phi_\tau^2}{\mathtt{c}^2 d\tau^2} \right) \sim g_{00} = \left( 1 - \frac{2 G M}{\mathtt{c}^2 r} \right)^{1/2} \qquad (4.1.3) $$
# $$ \xi = \frac{dH}{\tilde{H} d\phi_l} = \left( 1 - \frac{\breve{H}^2 d\phi_\tau^2}{\mathtt{c}^2 d\tau^2} \right)^{-1/2} \sim \left( 1 - \frac{2 G M}{\mathtt{c}^2 r} \right)^{-1/2} \qquad (4.1.3) $$
# Мы предполагаем, что эффект гравитационного взаимодействия достигается наложением множества потоков сложных объектов:
# $$ \breve{H} = \breve{H}_{ex} + \breve{H}_{self} \qquad (4.1.3) $$
# Тогда собственный поток одного из них в точке своей локации будет составлять некоторую долю от общего потока:
# $$ \breve{H}_{self} d\phi_\tau = \mathtt{c} d\tau - \breve{H}_{ex} d\phi_\tau = \mathtt{c} d\tau \left( 1 - \frac{\breve{H}_{ex} d\phi_\tau}{\mathtt{c} d\tau} \right) \qquad (4.1.4) $$
#
# Наметим также механизм моделирования эффектов ОТО. Закон сохранения количества полной фазы по внешней фазе в условиях различных прото-скоростей будет формировать сферу вокруг объекта с радиально изменяющимися параметрами:
# $$ ] \ dR \ne 0, R_s \ne R_l: \quad dH^2 = dR^2 + R_s^2 d\phi_s^2 + R_l^2 d\phi_l^2 \ \iff \ \frac{d\chi}{d\chi_l} = \left( 1 - \frac{d\chi_s^2}{d\chi^2} \right)^{-1/2} \sim g_{00} \qquad (2.5.4) $$
# Изменение фазы потока сложного объекта в его окресности (при отклонении по внешней фазе) будет
# В рамках моделирования эффектов СТО примем радиус в (2.1) постоянным, тогда скорости по прото-параметру будут:
# $$ \tilde{H} = \frac{dH}{d\chi} = R, \quad \frac{\partial H}{\partial \chi_s} = R, \quad \frac{\partial H}{\partial \chi_l} = R \qquad (2.1.1) $$
# Не сложно видеть, что условие количественного постоянства потока $ H $ в (2.2) накладывает ограничение на его распределение по осям. Воспользуемся этим:
# $$ ] \ d\chi_s = \cos \alpha \ d\alpha, \ d\chi_l = \imath \sin \alpha \ d\alpha: \quad \frac{dH}{d\alpha} = R e^{\alpha \imath} = e^{r + \alpha \imath}  \qquad (2.1.2)  $$
# В нашем случае и проблема, и её решение заключаются в том, что векторы $ d\chi_s, d\chi_l $ являются для нас базовыми и задают не только масштаб воспринимаемого пространства, но и восприятие времени.

# %%
$$ [ \breve{H} ], [ \breve{S} ], [ \breve{L} ]   = \left[ \frac{ \mathtt{прото-пространство} }{ \mathtt{прото-параметр 2} } \right] $$

# %% [markdown]
# $$
# H = \hat{\mathbf{q}} = e^{\Phi \mathbf{u}} = \cos \Phi + \mathbf{u} \sin\Phi
# $$
# $$
# dH = \frac{dH}{d\Phi} d\Phi = \tilde{H} d\Phi = \mathbf{u} \ e^{\Phi \mathbf{u}} \ d\Phi = (-\sin \Phi + \mathbf{u} \cos\Phi) d\Phi
# $$
# $$
# \frac{d\Phi}{dH} = \tilde{H}^{-1} = (-\sin \Phi - \mathbf{u} \cos\Phi) = - \mathbf{u} (\cos \Phi - \mathbf{u} \sin\Phi)
# $$
# $$
# d\chi^2 = - (\cos \chi - \mathbf{u} \sin\chi)^2 dH^2 = (-\cos^2 \chi + \sin^2 \chi + 2 \mathbf{u} \sin \chi \cos\chi )dH^2 = (\mathbf{u}\sin2\chi - \cos2\chi) dH^2 = \mathbf{u} e^{2\chi} \ dH^2
# $$
# $$
# d\chi^2 = d\chi_0^2 + d\chi_1^2
# $$
# $$
# \frac{dH}{d\chi} \frac{d\chi}{d\phi} \frac{d\phi}{dH} = 1 = \tilde{H} ??? \breve{H}^{-1}
# $$
# $$
# \frac{dH}{d\phi_0} \frac{d\phi_0}{d\phi_1}  = \frac{dH}{d\phi_1}
# $$
